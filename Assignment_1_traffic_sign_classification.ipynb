# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Dense, Dropout, Flatten
import matplotlib.pyplot as plt
from keras.optimizers import Adam
import seaborn as sns
import numpy as np
import pandas as pd
import pickle
import random
import cv2

# %%
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# Cloning into 'german-traffic-signs'...
# remote: Counting objects: 6, done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 0 (delta 0)
# Unpacking objects: 100% (6/6), done.

# %%
# !ls german-traffic-signs/
# Out:
# signnames.csv  test.p  train.p	valid.p

# %%
data= pd.read_csv("german-traffic-signs/signnames.csv")

# %%
data
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %%
with open("german-traffic-signs/train.p",mode='rb') as training:
  train = pickle.load(training)

# %%
with open("german-traffic-signs/valid.p",mode='rb') as validation:
  valid = pickle.load(validation)

# %%
with open("german-traffic-signs/test.p",mode='rb') as testing:
  test = pickle.load(testing)

# %%
X_train , y_train = train['features'], train['labels']
X_validation , y_validation = valid['features'], valid['labels']
X_test , y_test = test['features'], test['labels']

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %%
index=np.random.randint(1,len(X_train))
plt.imshow(X_train[index])
print("image label={}".format(y_train[index]))
# Out:
# image label=7

# %%
from sklearn.utils import shuffle
X_train , y_train = shuffle(X_train,y_train)

# %%
def preprocessing(img): 
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img = cv2.equalizeHist(img)
  img = img/255
  return img

# %%
X_train_processed = np.array(list(map(preprocessing,X_train)))
X_validation_processed = np.array(list(map(preprocessing,X_validation)))
X_test_processed = np.array(list(map(preprocessing,X_test)))

# %%
X_train_processed = X_train_processed.reshape(34799,32,32,1)
X_test_processed = X_test_processed.reshape(12630,32,32,1)
X_validation_processed = X_validation_processed.reshape(4410,32,32,1)

# %%
print(X_train_processed.shape)
print(X_test_processed.shape)
print(X_validation_processed.shape)
# Out:
# (34799, 32, 32, 1)
# (12630, 32, 32, 1)
# (4410, 32, 32, 1)

# %%
i= random.randint(1,len(X_train))
plt.imshow(X_train_processed[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_train[i].squeeze())

# %%
model=Sequential()
# added the convolutional layer
# filters, size of filters,input_shape,activation_function
model.add(Convolution2D(32,(5,5),activation='relu',input_shape=(32,32,1)))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# placed a dropout layer
model.add(Dropout(0.25))

# add another convolutional layer
model.add(Convolution2D(64,(5,5),activation='relu'))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten the image to 1 dimensional array
model.add(Flatten())

# add a dense layer : amount of nodes, activation
model.add(Dense(256,activation='relu'))

# place a dropout layer
# 0.5 drop out rate is recommended, half input nodes will be dropped at each update
model.add(Dropout(0.5))

# defining the ouput layer of our network
model.add(Dense(43,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 473,003
# Trainable params: 473,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_processed,
                    y_train,
                    batch_size=500,
                    epochs=50,
                    verbose=1,
                    validation_data=(X_validation_processed,y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 8s 234us/step - loss: 3.5636 - accuracy: 0.0607 - val_loss: 3.4638 - val_accuracy: 0.1580
# Epoch 2/50
# 34799/34799 [==============================] - 2s 47us/step - loss: 3.2952 - accuracy: 0.1577 - val_loss: 3.0742 - val_accuracy: 0.3000
# Epoch 3/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 2.7626 - accuracy: 0.3090 - val_loss: 2.4263 - val_accuracy: 0.4138
# Epoch 4/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 2.2318 - accuracy: 0.4154 - val_loss: 1.9558 - val_accuracy: 0.4633
# Epoch 5/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 1.8792 - accuracy: 0.4846 - val_loss: 1.6445 - val_accuracy: 0.5499
# Epoch 6/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 1.6322 - accuracy: 0.5376 - val_loss: 1.3848 - val_accuracy: 0.6274
# Epoch 7/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 1.4315 - accuracy: 0.5870 - val_loss: 1.1973 - val_accuracy: 0.6794
# Epoch 8/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 1.2778 - accuracy: 0.6254 - val_loss: 1.0634 - val_accuracy: 0.7073
# Epoch 9/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 1.1551 - accuracy: 0.6593 - val_loss: 0.9547 - val_accuracy: 0.7485
# Epoch 10/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 1.0542 - accuracy: 0.6874 - val_loss: 0.8609 - val_accuracy: 0.7730
# Epoch 11/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.9647 - accuracy: 0.7124 - val_loss: 0.7831 - val_accuracy: 0.7939
# Epoch 12/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.8909 - accuracy: 0.7327 - val_loss: 0.7161 - val_accuracy: 0.8141
# Epoch 13/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.8272 - accuracy: 0.7554 - val_loss: 0.6650 - val_accuracy: 0.8238
# Epoch 14/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.7724 - accuracy: 0.7694 - val_loss: 0.6311 - val_accuracy: 0.8302
# Epoch 15/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.7220 - accuracy: 0.7849 - val_loss: 0.5880 - val_accuracy: 0.8413
# Epoch 16/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.6696 - accuracy: 0.8000 - val_loss: 0.5458 - val_accuracy: 0.8469
# Epoch 17/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.6332 - accuracy: 0.8112 - val_loss: 0.5128 - val_accuracy: 0.8528
# Epoch 18/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.5946 - accuracy: 0.8219 - val_loss: 0.4982 - val_accuracy: 0.8619
# Epoch 19/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.5677 - accuracy: 0.8285 - val_loss: 0.4770 - val_accuracy: 0.8612
# Epoch 20/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.5391 - accuracy: 0.8403 - val_loss: 0.4558 - val_accuracy: 0.8637
# Epoch 21/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.5137 - accuracy: 0.8471 - val_loss: 0.4304 - val_accuracy: 0.8757
# Epoch 22/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.4849 - accuracy: 0.8570 - val_loss: 0.4197 - val_accuracy: 0.8789
# Epoch 23/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.4593 - accuracy: 0.8632 - val_loss: 0.4040 - val_accuracy: 0.8803
# Epoch 24/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.4413 - accuracy: 0.8689 - val_loss: 0.3887 - val_accuracy: 0.8853
# Epoch 25/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.4233 - accuracy: 0.8726 - val_loss: 0.3799 - val_accuracy: 0.8902
# Epoch 26/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.4061 - accuracy: 0.8799 - val_loss: 0.3648 - val_accuracy: 0.8943
# Epoch 27/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.3823 - accuracy: 0.8872 - val_loss: 0.3604 - val_accuracy: 0.8927
# Epoch 28/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.3664 - accuracy: 0.8923 - val_loss: 0.3378 - val_accuracy: 0.8995
# Epoch 29/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.3567 - accuracy: 0.8943 - val_loss: 0.3320 - val_accuracy: 0.9020
# Epoch 30/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.3415 - accuracy: 0.8996 - val_loss: 0.3260 - val_accuracy: 0.9029
# Epoch 31/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.3285 - accuracy: 0.9027 - val_loss: 0.3089 - val_accuracy: 0.9052
# Epoch 32/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.3126 - accuracy: 0.9070 - val_loss: 0.3049 - val_accuracy: 0.9102
# Epoch 33/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.3067 - accuracy: 0.9087 - val_loss: 0.3018 - val_accuracy: 0.9111
# Epoch 34/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2891 - accuracy: 0.9159 - val_loss: 0.2962 - val_accuracy: 0.9109
# Epoch 35/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2839 - accuracy: 0.9161 - val_loss: 0.2948 - val_accuracy: 0.9138
# Epoch 36/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.2750 - accuracy: 0.9181 - val_loss: 0.2918 - val_accuracy: 0.9118
# Epoch 37/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2641 - accuracy: 0.9209 - val_loss: 0.2801 - val_accuracy: 0.9156
# Epoch 38/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2540 - accuracy: 0.9252 - val_loss: 0.2659 - val_accuracy: 0.9193
# Epoch 39/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2499 - accuracy: 0.9255 - val_loss: 0.2690 - val_accuracy: 0.9188
# Epoch 40/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2390 - accuracy: 0.9303 - val_loss: 0.2666 - val_accuracy: 0.9193
# Epoch 41/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2318 - accuracy: 0.9296 - val_loss: 0.2622 - val_accuracy: 0.9200
# Epoch 42/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.2290 - accuracy: 0.9328 - val_loss: 0.2610 - val_accuracy: 0.9215
# Epoch 43/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2217 - accuracy: 0.9345 - val_loss: 0.2540 - val_accuracy: 0.9281
# Epoch 44/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2124 - accuracy: 0.9364 - val_loss: 0.2460 - val_accuracy: 0.9281
# Epoch 45/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.2047 - accuracy: 0.9399 - val_loss: 0.2507 - val_accuracy: 0.9254
# Epoch 46/50
# 34799/34799 [==============================] - 2s 46us/step - loss: 0.2027 - accuracy: 0.9405 - val_loss: 0.2427 - val_accuracy: 0.9279
# Epoch 47/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.1922 - accuracy: 0.9430 - val_loss: 0.2366 - val_accuracy: 0.9342
# Epoch 48/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.1883 - accuracy: 0.9441 - val_loss: 0.2314 - val_accuracy: 0.9308
# Epoch 49/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.1850 - accuracy: 0.9461 - val_loss: 0.2257 - val_accuracy: 0.9340
# Epoch 50/50
# 34799/34799 [==============================] - 2s 45us/step - loss: 0.1797 - accuracy: 0.9479 - val_loss: 0.2247 - val_accuracy: 0.9324

# %%
#score checking
score = model.evaluate(X_test_processed,y_test)
print('Test accuracy',score[1])
# Out:
# 12630/12630 [==============================] - 1s 70us/step
# Test accuracy 0.9167062640190125

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','validation'])
plt.title('Training and validation losses')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
#predicting
prediction = model.predict_classes(X_test_processed)
y_true_label= y_test

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_true_label,prediction)
plt.figure(figsize=(20,20))
sns.heatmap(matrix,annot=True)

# %%
L=6
W=6
fig , axes = plt.subplots(L,W,figsize=(12,12))
axes = axes.ravel()
for i in range(0,L*W):
  axes[i].imshow(X_test[i])
  axes[i].set_title('Prediction ={}\n True={}'.format(prediction[i],y_true_label[i]))
  axes[i].axis('off')
plt.subplots_adjust(wspace=1)

# %%
model.save('my_model.h5')
